# %% [markdown]
# <a href="https://colab.research.google.com/github/Joseonggwan/machine-learning-practice/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 첫번째 코랩 파일

# %% [markdown]
# # 나의 첫번쨰 코랩
# ## 실습내용
# ###실습1: Google의 Colab으로 첫번째 파일 생성
# ###실습2: Git 레포지토리 생성
# ###실습3: Colab제공 기능으로 github에 업로드하기

# %% [markdown]
# # Hello world 출력하기
# ## print 함수 사용

# %%
print('hello world')
print(1234)
print(1234)
# Out:
# hello world
# 1234
# 1234

# %% [markdown]
# ## 2. Tensorflow import 하기

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from '/usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py'>

# %%
tf.__version__
# Out:
# '2.19.0'
